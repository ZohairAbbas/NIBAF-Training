# %% [markdown]
# <a href="https://colab.research.google.com/github/chhotani18/NIBAF-Training/blob/master/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pandas allows for easy handling and manipulation of data, offering data structures for efficiently storing large datasets and tools for performing complex data analysis operations. It integrates seamlessly with other scientific libraries like NumPy, SciPy, and Matplotlib, making it an essential tool in the data science ecosystem.

# %%
##Read CSV file
from google.colab import files
import pandas as pd

# Step 2: Upload file using the upload widget
uploaded = files.upload()

# Step 3: Read the uploaded file into a Pandas DataFrame
# Get the name of the uploaded file (assuming you only upload one file)
for file_name in uploaded.keys():
    df = pd.read_csv(file_name)
# Out:
#      <input type="file" id="files-4e0c2373-5ade-44ad-ae98-a3873e20dbd0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4e0c2373-5ade-44ad-ae98-a3873e20dbd0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Create dataframe
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['New York', 'Los Angeles', 'Chicago']
}
df2 = pd.DataFrame(data)

# %%
df2
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago

# %%
##Read Excel File
# for file_name in uploaded.keys():
#     df = pd.read_excel(file_name)
#     f"First few rows of the uploaded file '{file_name}':")
#     df.head())

# %%
df
# Out:
#     gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0   Female   34                Yes             1              2           5
# 1   Female   23                Yes             4              3           2
# 2     Male   30                Yes             3              6           4
# 3     Male   22                Yes             2              1           3
# 4   Female   24                 No             2              1           3
# 5   Female   24                 No             7              5           4
# 6   Female   27                Yes             3              6           4
# 7     Male   21                Yes             2              3           7
# 8     Male   35                Yes             2              4           7
# 9     Male   31                Yes             1              3           7
# 10  Female   35                Yes             2              4           7
# ...

# %%
df.head() #Display the first 5 rows
# Out:
#    gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0  Female   34                Yes             1              2           5
# 1  Female   23                Yes             4              3           2
# 2    Male   30                Yes             3              6           4
# 3    Male   22                Yes             2              1           3
# 4  Female   24                 No             2              1           3
#
#    Government_Bonds  Fixed_Deposits  PPF  Gold  ...           Duration  \
# 0                 3               7    6     4  ...          1-3 years
# 1                 1               5    6     7  ...  More than 5 years
# 2                 2               5    1     7  ...          3-5 years
# 3                 7               6    4     5  ...   Less than 1 year
# 4                 6               4    5     7  ...   Less than 1 year
#
#   Invest_Monitor   Expect       Avenue What are your savings objectives?  \
# ...

# %%
df.tail()      # Display the last 5 rows
# Out:
#    gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 35   Male   30                Yes             1              4           6
# 36   Male   30                Yes             2              4           7
# 37   Male   25                Yes             5              4           7
# 38   Male   31                Yes             2              4           7
# 39   Male   29                Yes             4              3           5
#
#     Government_Bonds  Fixed_Deposits  PPF  Gold  ...   Duration  \
# 35                 5               3    2     7  ...  3-5 years
# 36                 5               1    3     6  ...  1-3 years
# 37                 6               1    2     3  ...  3-5 years
# 38                 5               3    1     6  ...  1-3 years
# 39                 7               2    1     6  ...  3-5 years
#
#    Invest_Monitor   Expect                 Avenue  \
# 35        Monthly  20%-30%         Fixed Deposits
# ...

# %%
df.shape)       # Display the dimensions of the DataFrame
# Out:
# (40, 24)

# %%
df.info())      # Display information about the DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   gender                             40 non-null     object
#  1   age                                40 non-null     int64
#  2   Investment_Avenues                 40 non-null     object
#  3   Mutual_Funds                       40 non-null     int64
#  4   Equity_Market                      40 non-null     int64
#  5   Debentures                         40 non-null     int64
#  6   Government_Bonds                   40 non-null     int64
#  7   Fixed_Deposits                     40 non-null     int64
#  8   PPF                                40 non-null     int64
#  9   Gold                               40 non-null     int64
#  10  Stock_Marktet                      40 non-null     object
# ...

# %%
df.describe())  # Display statistical summary
# Out:
#              age  Mutual_Funds  Equity_Market  Debentures  Government_Bonds  \
# count  40.000000     40.000000      40.000000   40.000000         40.000000
# mean   27.800000      2.550000       3.475000    5.750000          4.650000
# std     3.560467      1.197219       1.131994    1.675617          1.369072
# min    21.000000      1.000000       1.000000    1.000000          1.000000
# 25%    25.750000      2.000000       3.000000    5.000000          4.000000
# 50%    27.000000      2.000000       4.000000    6.500000          5.000000
# 75%    30.000000      3.000000       4.000000    7.000000          5.000000
# max    35.000000      7.000000       6.000000    7.000000          7.000000
#
#        Fixed_Deposits        PPF       Gold
# count       40.000000  40.000000  40.000000
# mean         3.575000   2.025000   5.975000
# std          1.795828   1.609069   1.143263
# min          1.000000   1.000000   2.000000
# 25%          2.750000   1.000000   6.000000
# ...

# %%
df['Source'] ##print one column
# Out:
# 0     Newspapers and Magazines
# 1        Financial Consultants
# 2                   Television
# 3                     Internet
# 4                     Internet
# 5                     Internet
# 6        Financial Consultants
# 7     Newspapers and Magazines
# 8                   Television
# 9     Newspapers and Magazines
# 10       Financial Consultants
# 11       Financial Consultants
# 12                    Internet
# 13    Newspapers and Magazines
# 14       Financial Consultants
# 15    Newspapers and Magazines
# 16                  Television
# 17       Financial Consultants
# 18    Newspapers and Magazines
# 19    Newspapers and Magazines
# 20       Financial Consultants
# 21    Newspapers and Magazines
# 22       Financial Consultants
# 23       Financial Consultants
# 24    Newspapers and Magazines
# 25       Financial Consultants
# 26       Financial Consultants
# 27                  Television
# 28                  Television
# 29    Newspapers and Magazines
# ...

# %%
 df[['Source', 'gender']]
# Out:
#                       Source  gender
# 0   Newspapers and Magazines  Female
# 1      Financial Consultants  Female
# 2                 Television    Male
# 3                   Internet    Male
# 4                   Internet  Female
# 5                   Internet  Female
# 6      Financial Consultants  Female
# 7   Newspapers and Magazines    Male
# 8                 Television    Male
# 9   Newspapers and Magazines    Male
# 10     Financial Consultants  Female
# 11     Financial Consultants    Male
# 12                  Internet  Female
# 13  Newspapers and Magazines  Female
# 14     Financial Consultants  Female
# 15  Newspapers and Magazines    Male
# 16                Television  Female
# 17     Financial Consultants    Male
# 18  Newspapers and Magazines    Male
# 19  Newspapers and Magazines    Male
# 20     Financial Consultants    Male
# 21  Newspapers and Magazines  Female
# 22     Financial Consultants    Male
# 23     Financial Consultants    Male
# ...

# %%
df['Source'][10:20] ##Print specific rows
# Out:
# 10       Financial Consultants
# 11       Financial Consultants
# 12                    Internet
# 13    Newspapers and Magazines
# 14       Financial Consultants
# 15    Newspapers and Magazines
# 16                  Television
# 17       Financial Consultants
# 18    Newspapers and Magazines
# 19    Newspapers and Magazines
# Name: Source, dtype: object

# %%
df.loc[1:8,['age']]
# Out:
#    age
# 1   23
# 2   30
# 3   22
# 4   24
# 5   24
# 6   27
# 7   21
# 8   35

# %%
df.iloc[1:3, 1:2]
# Out:
#    age
# 1   23
# 2   30

# %%
df[df['age'] > 30]
# Out:
#     gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0   Female   34                Yes             1              2           5
# 8     Male   35                Yes             2              4           7
# 9     Male   31                Yes             1              3           7
# 10  Female   35                Yes             2              4           7
# 25  Female   32                Yes             3              4           7
# 27    Male   31                Yes             2              3           7
# 29  Female   34                Yes             5              4           3
# 31  Female   31                Yes             2              4           7
# 38    Male   31                Yes             2              4           7
#
#     Government_Bonds  Fixed_Deposits  PPF  Gold  ...   Duration  \
# 0                  3               7    6     4  ...  1-3 years
# 8                  5               3    1     6  ...  1-3 years
# ...

# %%
df['Country'] = "Pakistan"
df
# Out:
#     gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0   Female   34                Yes             1              2           5
# 1   Female   23                Yes             4              3           2
# 2     Male   30                Yes             3              6           4
# 3     Male   22                Yes             2              1           3
# 4   Female   24                 No             2              1           3
# 5   Female   24                 No             7              5           4
# 6   Female   27                Yes             3              6           4
# 7     Male   21                Yes             2              3           7
# 8     Male   35                Yes             2              4           7
# 9     Male   31                Yes             1              3           7
# 10  Female   35                Yes             2              4           7
# ...

# %%
df.isnull().sum()
# Out:
# gender                               0
# age                                  0
# Investment_Avenues                   0
# Mutual_Funds                         0
# Equity_Market                        0
# Debentures                           0
# Government_Bonds                     0
# Fixed_Deposits                       0
# PPF                                  0
# Gold                                 0
# Stock_Marktet                        0
# Factor                               0
# Objective                            0
# Purpose                              0
# Duration                             0
# Invest_Monitor                       0
# Expect                               0
# Avenue                               0
# What are your savings objectives?    0
# Reason_Equity                        0
# Reason_Mutual                        0
# Reason_Bonds                         0
# Reason_FD                            0
# Source                               0
# ...

# %%
df['age'].fillna(df['age'].mean(), inplace=True)

# %%
# Identify numeric columns
numeric_cols = df.select_dtypes(include='number').columns
"Numeric columns:", numeric_cols
# Out:
# ('Numeric columns:',
#  Index(['age', 'Mutual_Funds', 'Equity_Market', 'Debentures',
#         'Government_Bonds', 'Fixed_Deposits', 'PPF', 'Gold'],
#        dtype='object'))

# %%
grouped_data = df.groupby('Source')[numeric_cols].sum()
grouped_data
# Out:
#                           age  Mutual_Funds  Equity_Market  Debentures  \
# Source
# Financial Consultants     447            43             61          97
# Internet                   91            12              9          13
# Newspapers and Magazines  394            31             46          88
# Television                180            16             23          32
#
#                           Government_Bonds  Fixed_Deposits  PPF  Gold
# Source
# Financial Consultants                   77              48   25    97
# Internet                                23              18   16    21
# Newspapers and Magazines                61              53   29    84
# Television                              25              24   11    37

# %%
agg_data = df.groupby('Source')[numeric_cols].agg({'age': 'mean', 'Gold': 'sum'})
agg_data
# Out:
#                                 age  Gold
# Source
# Financial Consultants     27.937500    97
# Internet                  22.750000    21
# Newspapers and Magazines  28.142857    84
# Television                30.000000    37

# %%
df.to_csv('modified_dataset.csv', index=False)
